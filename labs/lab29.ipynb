# %% [markdown]
# # Лабораторная 12. Ассоциативные правила

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
df = pd.read_csv('heart.csv')
df = df.dropna()
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
df = df.ffill(axis=1)
df
# Out:
#        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1     53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2     70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3     61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4     62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 1020  59.0  1.0  1.0     140.0  221.0  0.0      1.0    164.0    1.0      0.0
# 1021  60.0  1.0  0.0     125.0  258.0  0.0      0.0    141.0    1.0      2.8
# 1022  47.0  1.0  0.0     110.0  275.0  0.0      0.0    118.0    1.0      1.0
# 1023  50.0  0.0  0.0     110.0  254.0  0.0      0.0    159.0    0.0      0.0
# 1024  54.0  1.0  0.0     120.0  188.0  0.0      1.0    113.0    0.0      1.4
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0     0.0
# 1       0.0  0.0   3.0     0.0
# 2       0.0  0.0   3.0     0.0
# 3       2.0  1.0   3.0     0.0
# 4       1.0  3.0   2.0     0.0
# ...     ...  ...   ...     ...
# 1020    2.0  0.0   2.0     1.0
# 1021    1.0  1.0   3.0     0.0
# 1022    1.0  1.0   2.0     0.0
# 1023    2.0  0.0   2.0     1.0
# 1024    1.0  1.0   3.0     0.0
#
# [1025 rows x 14 columns]

# %%
transactions = []
for i in range(0, 1000):
    transactions.append([str(df.values[i,j]) for j in range(0, 14)])

# %%
result = list(apriori(transactions, min_support = 0.01, min_confidence = 0.1, min_lift = 4, min_length = 2))

# %%
association_results = list(result)

# %%
print(len(result))
# Out:
# 62

# %%
rules=[]
for item in result:

    # первый индекс внутреннего списка
    # Содержит базовый предмет и добавляет предмет
    pair = item[0]
    items = [x for x in pair]
    v1=str(items[0])
    v2= str(items[1])

    #второй индекс внутреннего списка
    v3= str(item[1])

    #третий индекс списка, расположенный на 0-м месте
    #третьего индекса внутреннего списка

    v4= str(item[2][0][2])
    v5=str(item[2][0][3])
    rows=(v1,v2,v3,v4,v5)
    rules.append(rows)
label=['title1','title2','suppot','confidence','lift']
nm=pd.DataFrame.from_records(rules,columns=label)
nm
# Out:
#    title1 title2 suppot           confidence                lift
# 0   150.0    1.6  0.012  0.33333333333333337   4.166666666666667
# 1    54.0  108.0  0.011   0.4074074074074074   7.834757834757835
# 2   160.0  112.0   0.01   0.2857142857142857   4.081632653061224
# 3   128.0   52.0   0.01  0.25641025641025644  6.1050061050061055
# 4   130.0  256.0  0.011                  1.0     7.2992700729927
# ..    ...    ...    ...                  ...                 ...
# 57    0.0    1.0  0.011                  1.0   8.695652173913043
# 58    0.0    1.0   0.01                0.625  4.6992481203007515
# 59    0.0    1.0   0.01  0.18181818181818182   4.784688995215311
# 60    0.0    1.0  0.011  0.19999999999999998  10.526315789473683
# 61    0.0    1.0   0.01                0.125   4.166666666666667
#
# [62 rows x 5 columns]

# %%
nm.sort_values(by=['lift'], ascending=False).head(20)
# Out:
#    title1 title2 suppot           confidence               lift
# 55    0.0  108.0  0.011   0.4074074074074074  9.474590869939707
# 23   54.0  108.0  0.011   0.4074074074074074  9.474590869939707
# 39    0.0   54.0  0.011   0.4074074074074074  9.474590869939707
# 47    2.0   54.0  0.011   0.4074074074074074  9.474590869939707
# 57    0.0    1.0  0.011                  1.0  8.695652173913043
# 49  130.0    2.0  0.011                  1.0  8.695652173913043
# 25  130.0    2.0  0.011                  1.0  8.403361344537815
# 41    0.0  130.0  0.011                  1.0  8.403361344537815
# 1    54.0  108.0  0.011   0.4074074074074074  7.834757834757835
# 15   54.0  108.0  0.011   0.4074074074074074  7.834757834757835
# 31    0.0   54.0  0.011   0.4074074074074074  7.834757834757835
# 8     0.0   54.0  0.011   0.4074074074074074  7.834757834757835
# 35    0.0  130.0  0.011                  1.0  7.518796992481203
# 19  130.0    1.0  0.011                  1.0  7.518796992481203
# 11    0.0  130.0  0.011                  1.0    7.2992700729927
# 4   130.0  256.0  0.011                  1.0    7.2992700729927
# 37    4.0    0.0  0.011  0.19999999999999998  6.666666666666666
# 21    4.0  138.0  0.011  0.19999999999999998  6.666666666666666
# 6   138.0    4.0  0.011  0.19999999999999998  6.666666666666666
# 13    0.0  138.0  0.011  0.19999999999999998  6.666666666666666
